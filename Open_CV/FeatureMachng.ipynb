# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def display(img, cmap='gray'):
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap=cmap)

# Try to load the image
image_path = 'Resources/rees.jpeg'
reeses = cv2.imread(image_path, 0)

if reeses is not None:
    # Convert the data type to float
    reeses = reeses.astype(float)

    # Display the image
    display(reeses)
else:
    print(f"Failed to load the image from '{image_path}'. Check the file path and format.")

# %%
mage_path1 = 'Resources/rees.jpeg'
mage_path1 = 'Resources/reesbuncg.jpeg'
reeses = cv2.imread(image_path, 0)

if reeses is not None:
    # Convert the data type to float
    reeses = reeses.astype(float)

    # Display the image
    display(reeses)
else:
    print(f"Failed to load the image from '{image_path}'. Check the file path and format.")

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def display(img, cmap='gray'):
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap=cmap)

# Try to load the image
image_path1 = 'Resources/rees.jpeg'
image_path2 = 'Resources/reesbuncg.jpeg'
reeses1 = cv2.imread(image_path, 0)
reeses2 = cv2.imread(image_path, 0)
if reeses is not None:
    # Convert the data type to float
    reeses1 = reeses1.astype(float)
    reeses2 = reeses2.astype(float)

    # Display the image
    display(reeses1)
    display(reeses2)
else:
    print(f"Failed to load the image from '{image_path1}'. Check the file path and format.")
    print(f"Failed to load the image from '{image_path2}'. Check the file path and format.")
