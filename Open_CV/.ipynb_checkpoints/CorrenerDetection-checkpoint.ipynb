# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread('Resources/flat_chess.jpg')
flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flat_chess)

# %%
plt.imshow(flat_chess ,cmap='gray')

# %%
flat_chess=cv2.cvtColor(flat_chess,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(flat_chess ,cmap='gray')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

flat_chess = cv2.imread('Resources/flat_chess.jpg')
flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_BGR2RGB)

gray_flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_flat_chess ,cmap='gray')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

flat_chess = cv2.imread('Resources/flat_chess.jpg')
flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_BGR2RGB)

gray_flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_flat_chess ,cmap='gray')

gray = np.float32(gray_flat_chess)
dst  = cv2.cornerHarris(src=gray ,blockSize=2,ksize=3,k=0.04)
dst = cv2.dilate(dst,None)
flat_chess[dst>0.01*dst.max()]=[255,0,0]
plt.imshow(flat_chess)

# %%
gray = np.float32(gray_flat_chess)
dst  = cv2.cornerHarris(src=gray ,blockSize=2,ksize=3,k=0.04)

# %%
dst = cv2.dilate(dst,None)

# %%
flat_chess[dst>0.01*dst.max()]=[255,0,0]

# %%
plt.imshow(flat_chess)

# %%
#cornerHarris method for correnr detection
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

flat_chess = cv2.imread('Resources/flat.png')
flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_BGR2RGB)

gray_flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_flat_chess ,cmap='gray')

gray = np.float32(gray_flat_chess)
dst  = cv2.cornerHarris(src=gray ,blockSize=2,ksize=3,k=0.04)
dst = cv2.dilate(dst,None)
flat_chess[dst>0.01*dst.max()]=[255,0,0]
plt.imshow(flat_chess)
